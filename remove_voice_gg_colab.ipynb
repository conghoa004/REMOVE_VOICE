# %% [markdown]
# # Vocal Separation using BS-Roformer
#
# This notebook demonstrates how to separate vocals and instrumentals from an audio file using the state-of-the-art **BS-Roformer** model.
#
# > **Note:** If you are running this notebook on Kaggle, it is highly recommended to enable the **GPU T4** accelerator for significantly faster inference.

# %% [markdown]
# ## Step 1: Install BS-Roformer Library
#
# Install the `bs-roformer-infer` package which provides the command-line tools for model downloading and inference.

# %%
# Install the BS-Roformer inference library silently
# !pip install -q bs-roformer-infer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.7 MB/s eta 0:00:00

# %% [markdown]
# ## Step 2: List Available Models
#
# Check the list of available pre-trained models to choose the most suitable one.

# %%
# Display the list of available pre-trained BS-Roformer models
# !bs-roformer-download --list-models
# Out:
# Name                                                             Category      Checkpoint
# -----------------------------------------------------------------------------------------
# Roformer Model: BS Roformer SW by jarredou                       multi-stem    BS-Rofo-SW-Fixed.ckpt
# Roformer Model: BS Roformer | Chorus Male-Female by Sucial       vocals        model_chorus_bs_roformer_ep_267_sdr_24.1275.ckpt
# Roformer Model: BS Roformer | Instrumental Resurrection by unwa  instrumental  bs_roformer_instrumental_resurrection_unwa.ckpt
# Roformer Model: BS Roformer | Male-Female by aufr33              vocals        bs_roformer_male_female_by_aufr33_sdr_7.2889.ckpt
# Roformer Model: BS Roformer | Vocals Resurrection by unwa        vocals        bs_roformer_vocals_resurrection_unwa.ckpt
# Roformer Model: BS Roformer | Vocals Revive V2 by Unwa           vocals        bs_roformer_vocals_revive_v2_unwa.ckpt
# Roformer Model: BS Roformer | Vocals Revive V3e by Unwa          vocals        bs_roformer_vocals_revive_v3e_unwa.ckpt
# Roformer Model: BS Roformer | Vocals Revive by Unwa              vocals        bs_roformer_vocals_revive_unwa.ckpt
# Roformer Model: BS Roformer | Vocals by Gabox                    vocals        bs_roformer_vocals_gabox.ckpt
# Roformer Model: BS-Roformer-De-Reverb                            dereverb      deverb_bs_roformer_8_384dim_10depth.ckpt
#
# Available categories: dereverb, instrumental, multi-stem, vocals

# %% [markdown]
# ## Step 3: Download the Vocals Resurrection Model
#
# Download the recommended high-performance vocals resurrection model by Unwa. The downloaded assets will be stored in the `models` directory.

# %%
# Download the high-quality vocals separation model by Unwa
# !bs-roformer-download \
--model roformer-model-bs-roformer-vocals-resurrection-by-unwa \
--output-dir models
# Out:
# 📦 Preparing Roformer Model: BS Roformer | Vocals Resurrection by unwa (vocals)
#
# 🔄 Downloading Roformer Model: BS Roformer | Vocals Resurrection by unwa checkpoint...
# Downloading Roformer Model: BS Roformer | Vocals Resurrection by unwa checkpoint (attempt 1/3)...
# Roformer Model: BS Roformer | Vocals Resurrection by unwa checkpoint: 100%|█| 19
# ✓ Successfully downloaded: models/roformer-model-bs-roformer-vocals-resurrection-by-unwa/bs_roformer_vocals_resurrection_unwa.ckpt
#   File size: 204,510,749 bytes
#   SHA256 verified: 9dbfe5cb572e4ed32a15ec727d7bd06c8d7aba97509e6fda5bc008bb1e0b2dd5
#
# 🔄 Downloading Roformer Model: BS Roformer | Vocals Resurrection by unwa config...
# Downloading Roformer Model: BS Roformer | Vocals Resurrection by unwa config (attempt 1/3)...
# Roformer Model: BS Roformer | Vocals Resurrection by unwa config: 2.57kB [00:00, 12.3MB/s]
# ✓ Successfully downloaded: models/roformer-model-bs-roformer-vocals-resurrection-by-unwa/config_bs_roformer_vocals_resurrection_unwa.yaml
#   File size: 2,633 bytes
#   SHA256 verified: 79c65b6158c8e9236c9f02247cbb2fb6eb0007c42c47799e9de8e86f474556c6
#
# ==================================================
# 🎉 Downloads complete
# 📁 Assets stored in: models

# %% [markdown]
# ## Step 4: Install FFmpeg
#
# FFmpeg is required for audio decoding, encoding, and conversion.

# %%
# Install FFmpeg package silently using apt-get
# !apt-get -qq install ffmpeg

# %% [markdown]
# ## Step 5: Convert Input Audio to WAV Format
#
# Convert the input audio file to WAV format with a 44100 Hz sample rate and stereo (2 channels) layout for optimal compatibility
# If the input file is already in WAV format, skip this conversion step and use the original WAV file directly.

# %%
# Convert input MP3 audio to a 44100Hz, stereo WAV file
# !ffmpeg -i "/content/Hngle - Tìm em ft. Bảo Anh  Official Music Video - HNGLE _ hưng lê.mp3" \
-ar 44100 -ac 2 \
"./input_music.wav"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x56c33c5fd4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/Hngle - Tìm em ft. Bảo Anh  Official Music Video - HNGLE _ hưng lê.mp3':
#   Metadata:
#     artist          : HNGLE / hưng lê
#     title           : Hngle - Tìm em ft. Bảo Anh | Official Music Video
#     encoder         : Lavf60.3.100
#   Duration: 00:04:32.14, start: 0.000000, bitrate: 320 kb/s
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to './input_music.wav':
#   Metadata:
#     IART            : HNGLE / hưng lê
#     INAM            : Hngle - Tìm em ft. Bảo Anh | Official Music Video
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=   46880kB time=00:04:32.13 bitrate=1411.2kbits/s speed= 317x
# video:0kB audio:46880kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000346%

# %% [markdown]
# ## Step 6: Run BS-Roformer Inference
#
# Run the source separation inference to separate the vocal and instrumental components of the track.

# %%
# Run BS-Roformer inference to separate vocals and instrumentals
# !bs-roformer-infer \
--config_path /content/models/roformer-model-bs-roformer-vocals-resurrection-by-unwa/config_bs_roformer_vocals_resurrection_unwa.yaml \
--model_path /content/models/roformer-model-bs-roformer-vocals-resurrection-by-unwa/bs_roformer_vocals_resurrection_unwa.ckpt \
--input_folder "/content" \
--store_dir "./output"
# Out:
# Non-A100 GPU detected, using math or mem efficient attention if input tensor is on cuda
# /usr/local/lib/python3.13/dist-packages/torch/functional.py:681: UserWarning: A window was not provided. A rectangular window will be applied,which is known to cause spectral leakage. Other windows such as torch.hann_window or torch.hamming_window are recommended to reduce spectral leakage.To suppress this warning and use a rectangular window, explicitly set `window=torch.ones(n_fft, device=<device>)`. (Triggered internally at /pytorch/aten/src/ATen/native/SpectralOps.cpp:835.)
#   return _VF.stft(  # type: ignore[attr-defined]
# Using model weights: /content/models/roformer-model-bs-roformer-vocals-resurrection-by-unwa/bs_roformer_vocals_resurrection_unwa.ckpt
# Total tracks found: 1
# Tracks:   0% 0/1 [00:00<?, ?track/s]
# Processing track 1/1: input_music.wav
# /usr/local/lib/python3.13/dist-packages/bs_roformer/utils.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/lib/python3.13/contextlib.py:109: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# Estimated total processing time for this track: 85.91 seconds
# Estimated time remaining: 0.00 seconds
# Tracks: 100% 1/1 [00:52<00:00, 52.12s/track]
# Elapsed time: 53.13 sec
